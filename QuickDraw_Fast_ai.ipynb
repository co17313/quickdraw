# %% [markdown]
# # QuickDraw
#
# This dataset was collected by Google from people drawing different objects. The dataset is a collection of 50 million drawings from 345 different objects that is available publically for everyone.
#
#
#
# ![alt text](https://raw.githubusercontent.com/googlecreativelab/quickdraw-dataset/master/preview.jpg)

# %% [markdown]
# ## Mounting Google Drive for Persistence

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/'
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Downloading the dataset from kaggle

# %%
! wget -x --load-cookies cookies.txt "https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/10200/868375/upload/train_simplified.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1592303422&Signature=UCC2b45QV4JHLmn2B0xQEqAQ9sDJuJRpzyH5gP%2FbByBich5LK4CUcY9Q78GNbF4aMSs4%2FIIdLQA7ONv4v0xpr5sUM99L0%2B9CISE15UjvXyPofR%2FMDL%2ByiVT3gKBt5iWohCOPuplonTEH2N4JSVCJrS3qibyz1KOfL%2FpQ8dc3%2FEQtUNPeM1A1QprkGUUOAR3sApKNrRrm9h7iNKV86nYCRgHmquq%2Fi8NWotBQ5qnB6K%2BUL7gelQdWYq64%2B%2Fy0qxP8cA4HKaC3pKARyEQ%2ByGyDRq8KosP7qzS3bb2XPWhUxCO3ufOA8zfOLFZes7RvIILWQR5bdDRyw%2FMEbAY%2BLhcvmg%3D%3D&response-content-disposition=attachment%3B+filename%3Dtrain_simplified.zip"
# Out:
# The name is too long, 621 chars total.
# Trying to shorten...
# New name is storage.googleapis.com/kaggle-competitions-data/kaggle-v2/10200/868375/upload/train_simplified.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1592303422&Signature=UCC2b45QV4JHLmn2B0xQEqAQ9sDJuJRpzyH5gP%2FbByBi.
# --2020-06-13 10:51:34--  https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/10200/868375/upload/train_simplified.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1592303422&Signature=UCC2b45QV4JHLmn2B0xQEqAQ9sDJuJRpzyH5gP%2FbByBich5LK4CUcY9Q78GNbF4aMSs4%2FIIdLQA7ONv4v0xpr5sUM99L0%2B9CISE15UjvXyPofR%2FMDL%2ByiVT3gKBt5iWohCOPuplonTEH2N4JSVCJrS3qibyz1KOfL%2FpQ8dc3%2FEQtUNPeM1A1QprkGUUOAR3sApKNrRrm9h7iNKV86nYCRgHmquq%2Fi8NWotBQ5qnB6K%2BUL7gelQdWYq64%2B%2Fy0qxP8cA4HKaC3pKARyEQ%2ByGyDRq8KosP7qzS3bb2XPWhUxCO3ufOA8zfOLFZes7RvIILWQR5bdDRyw%2FMEbAY%2BLhcvmg%3D%3D&response-content-disposition=attachment%3B+filename%3Dtrain_simplified.zip
# ...

# %%
! mv "/content/storage.googleapis.com/kaggle-competitions-data/kaggle-v2/10200/868375/upload/train_simplified.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1592303422&Signature=UCC2b45QV4JHLmn2B0xQEqAQ9sDJuJRpzyH5gP%2FbByBi" "/content/gdrive/My Drive/fastai-v3/train.zip"

# %%
! wget -x --load-cookies cookies.txt "https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/10200/868375/compressed/test_simplified.csv.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1592305310&Signature=HD1AOM%2Fj18U%2FzKrxoyvvkUeE9KE1%2FdhUIB9v5edQ96UgEiC%2FGJ40hTgDpjOaF3FRS%2BIbjJOoYOu%2F8VjmdjJUECw7YLGeXSz3PG2M9UNFir%2Fc1GJoQECdMtH8cRHyMaR8%2Btcrgx5PzKGyfXFU5Wp3ANmIbuFCwhhF9%2BXNoMWB7fGCQXjDN3ta11fa03e5mkNpfDyg9z%2F6nlrXcUbXKYSTh4JRjDopqU2OxWMiESYQLo4PUVYyfrZ1TMAcIRDfsYFcBMhd%2FjdfWzCsFjJw5psLA7mIW%2F7cXuHbFIbYAaUslkB1gfgG2beJmxpyFFBipzyyWDEX2ZXoH42AVL10OVUNew%3D%3D&response-content-disposition=attachment%3B+filename%3Dtest_simplified.csv.zip"
# Out:
# The name is too long, 633 chars total.
# Trying to shorten...
# New name is storage.googleapis.com/kaggle-competitions-data/kaggle-v2/10200/868375/compressed/test_simplified.csv.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1592305310&Signature=HD1AOM%2Fj18U%2FzKrxoyvvkUeE9KE1%2FdhUI.
# --2020-06-13 11:02:21--  https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/10200/868375/compressed/test_simplified.csv.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1592305310&Signature=HD1AOM%2Fj18U%2FzKrxoyvvkUeE9KE1%2FdhUIB9v5edQ96UgEiC%2FGJ40hTgDpjOaF3FRS%2BIbjJOoYOu%2F8VjmdjJUECw7YLGeXSz3PG2M9UNFir%2Fc1GJoQECdMtH8cRHyMaR8%2Btcrgx5PzKGyfXFU5Wp3ANmIbuFCwhhF9%2BXNoMWB7fGCQXjDN3ta11fa03e5mkNpfDyg9z%2F6nlrXcUbXKYSTh4JRjDopqU2OxWMiESYQLo4PUVYyfrZ1TMAcIRDfsYFcBMhd%2FjdfWzCsFjJw5psLA7mIW%2F7cXuHbFIbYAaUslkB1gfgG2beJmxpyFFBipzyyWDEX2ZXoH42AVL10OVUNew%3D%3D&response-content-disposition=attachment%3B+filename%3Dtest_simplified.csv.zip
# ...

# %% [markdown]
# ## Unzipping the data

# %%
! mv "/content/storage.googleapis.com/kaggle-competitions-data/kaggle-v2/10200/868375/compressed/test_simplified.csv.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1592305310&Signature=HD1AOM%2Fj18U%2FzKrxoyvvkUeE9KE1%2FdhUI" "/content/gdrive/My Drive/fastai-v3"

# %%
! unzip "/content/gdrive/My Drive/fastai-v3/train.zip" -d "/content/gdrive/My Drive/fastai-v3/data/train_simplified"

# %%
! unzip "/content/gdrive/My Drive/fastai-v3/test_simplified.zip" -d "/content/gdrive/My Drive/fastai-v3/data/"
# Out:
# Archive:  /content/gdrive/My Drive/fastai-v3/test_simplified.zip
#   inflating: /content/gdrive/My Drive/fastai-v3/data/test_simplified.csv

# %% [markdown]
# ## Installing Fast.ai

# %%
# !curl -s https://course.fast.ai/setup/colab 9 | bash
# !pip uninstall torch torchvision -y
# !pip install torch==1.4.0 torchvision==0.5.0
# Out:
# Updating fastai...
# Done.
# Uninstalling torch-1.5.1+cu101:
#   Successfully uninstalled torch-1.5.1+cu101
# Uninstalling torchvision-0.6.1+cu101:
#   Successfully uninstalled torchvision-0.6.1+cu101
# ...
#      |████████████████████████████████| 753.4MB 22kB/s
# ...
#      |████████████████████████████████| 4.0MB 34.1MB/s
# ...

# %% [markdown]
# ## Importng Libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pathlib import Path

from fastai import *
from fastai.vision import *

import json

# %% [markdown]
# ## Getting utilities from Github

# %%
! wget https://gist.githubusercontent.com/ab63/abd02b6a3b61a9e60067faf7821ee95a/raw/577d023dac9ea4837e0eb343fb69b59c9f9a6a31/utils.py
# Out:
# --2020-06-29 07:02:25--  https://gist.githubusercontent.com/ab63/abd02b6a3b61a9e60067faf7821ee95a/raw/577d023dac9ea4837e0eb343fb69b59c9f9a6a31/utils.py
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3270 (3.2K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   3.19K  --.-KB/s    in 0s
#
# 2020-06-29 07:02:25 (45.4 MB/s) - ‘utils.py’ saved [3270/3270]

# %%
from utils import *

# %%
NUM_SAMPLES_PER_CLASS = 1_000
NUM_VAL = 50 * 340

# %% [markdown]
# ## Preprocessing the data

# %%
PATH = Path('/content/data/txt')

# %%
PATH.mkdir(exist_ok=True)
(PATH/'train').mkdir(exist_ok=True)
(PATH/'test').mkdir(exist_ok=True)

# %%
def create_train_txts_from_df(path):
    df = pd.read_csv(path)
    klass = '_'.join(path.stem.split())
    (PATH/'train'/klass).mkdir(exist_ok=True)
    for row in df.sample(NUM_SAMPLES_PER_CLASS).iterrows():
        example = {
            'countrycode': row[1].countrycode,
            'drawing': json.loads(row[1].drawing),
            'key_id': row[1].key_id,
            'recognized': row[1].recognized
        }
        with open(PATH/'train'/klass/f'{example["key_id"]}.txt', mode='w') as f: json.dump(example, f)

def create_test_txts_from_df(path):
    df = pd.read_csv(path)
    for row in df.iterrows():
        example = {
            'countrycode': row[1].countrycode,
            'drawing': json.loads(row[1].drawing),
            'key_id': row[1].key_id
        }
        with open(PATH/'test'/f'{example["key_id"]}.txt', mode='w') as f: json.dump(example, f)

# %%
 ! cp '/content/gdrive/My Drive/fastai-v3/data/test_simplified.csv' '/content/test_simplified.csv'

# %%
# %time create_test_txts_from_df('/content/gdrive/My Drive/fastai-v3/data/test_simplified.csv')
# Out:
# CPU times: user 1min 4s, sys: 8.36 s, total: 1min 12s
# Wall time: 1min 13s

# %%
# %time for p in Path('/content/gdrive/My Drive/fastai-v3/data/train').iterdir(): create_train_txts_from_df(p)
# Out:
# CPU times: user 7min 52s, sys: 43.2 s, total: 8min 35s
# Wall time: 14min

# %%
sz = 128
bs = 640

# %%
class JSONImageItemList(ImageList):
  def open(self,fn):
    with io.open(fn) as f: j = json.load(f)
    drawing = list2drawing(j['drawing'], size=sz)
    tensor = drawing2tensor(drawing)
    return Image(tensor.div_(255))

# %%
item_list = JSONImageItemList.from_folder(PATH/'train', extensions=[".txt"])

# %%
idxs = np.arange(item_list.items.shape[0])
np.random.shuffle(idxs)
val_idxs = idxs[:NUM_VAL]

# %%
item_lists = item_list.split_by_idx(val_idxs)

# %%
label_lists = item_lists.label_from_folder()
pd.to_pickle(label_lists.train.y.classes, 'data/classes.pkl')

# %%
classes = pd.read_pickle('data/classes.pkl')

label_lists = item_lists.label_from_folder(classes=classes)

test_items = JSONImageItemList.from_folder(PATH/'test', extensions=[".txt"])
label_lists.add_test(test_items);

# %%
train_dl = DataLoader(label_lists.train, bs, True, num_workers=0)
valid_dl = DataLoader(label_lists.valid, 2*bs, False, num_workers=0)
test_dl = DataLoader(label_lists.test, 2*bs, False, num_workers=0)

data_bunch = ImageDataBunch(train_dl, valid_dl, test_dl)

# %%
pd.to_pickle(data_bunch.batch_stats(), f'data/batch_stats_{sz}_0worker.pkl')

# %%
batch_stats = pd.read_pickle(f'data/batch_stats_{sz}_0worker.pkl')

# %%
data_bunch.normalize(batch_stats);

# %%
data_bunch.show_batch(rows=4)

# %%
name = f'res34-{sz}-0-worker'

# %% [markdown]
# ## Creating the model

# %%
learn = cnn_learner(data_bunch, models.resnet34, metrics=[accuracy, map3])

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>map3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.419363</td>
#       <td>1.927069</td>
#       <td>0.537412</td>
#       <td>0.628265</td>
#       <td>19:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.885922</td>
#       <td>1.587367</td>
#       <td>0.610118</td>
#       <td>0.697157</td>
#       <td>15:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.660683</td>
#       <td>1.453290</td>
#       <td>0.643353</td>
#       <td>0.725677</td>
#       <td>14:56</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.575172</td>
#       <td>1.419136</td>
#       <td>0.652941</td>
#       <td>0.732745</td>
#       <td>14:56</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(f'{name}-stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>map3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
# ...

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(6, max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>map3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.523104</td>
#       <td>1.361741</td>
#       <td>0.662824</td>
#       <td>0.741912</td>
#       <td>18:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.445113</td>
#       <td>1.294126</td>
#       <td>0.676294</td>
#       <td>0.754412</td>
#       <td>18:50</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.350219</td>
#       <td>1.250226</td>
#       <td>0.686118</td>
#       <td>0.762441</td>
#       <td>18:48</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.282817</td>
#       <td>1.224907</td>
#       <td>0.693941</td>
#       <td>0.768255</td>
#       <td>18:49</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.save(f'{name}-stage-1-slice')

# %%
learn.load('res34-128-0-worker-stage-1')

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(6, max_lr=6e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>map3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.466493</td>
#       <td>1.392551</td>
#       <td>0.652765</td>
#       <td>0.733480</td>
#       <td>18:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.356945</td>
#       <td>1.268441</td>
#       <td>0.680529</td>
#       <td>0.758451</td>
#       <td>18:51</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.164879</td>
#       <td>1.139492</td>
#       <td>0.713059</td>
#       <td>0.785304</td>
#       <td>18:50</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.931050</td>
#       <td>1.043272</td>
#       <td>0.737118</td>
#       <td>0.805108</td>
#       <td>18:50</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.save(f'{name}-stage-3-maxlr')

# %%
! cp "/content/models/res34-128-0-worker-stage-3-maxlr.pth" "/content/gdrive/My Drive/fastai-v3/res34-128-0-worker-stage-3-maxlr.pth"

# %%
learn.load('res34-128-0-worker-stage-3-maxlr')

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(10,max_lr=6e-4,start_epoch=7)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>map3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
# ...

# %%
learn.load('/content/gdrive/My Drive/fastai-v3/res34-128-0-worker-stage-3-maxlr')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (323000 items)
# x: JSONImageItemList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# van,van,van,van,van
# Path: /content/data/txt/train;
#
# Valid: LabelList (17000 items)
# x: JSONImageItemList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# The_Great_Wall_of_China,elbow,table,skull,hedgehog
# Path: /content/data/txt/train;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
# ...

# %%
learn.export("export.pkl")

# %% [markdown]
# ## Resnet50

# %%
learn = cnn_learner(data_bunch, models.resnet50, metrics=[accuracy, map3])

# %%
learn.fit_one_cycle(4)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/4 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>map3</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
# ...
